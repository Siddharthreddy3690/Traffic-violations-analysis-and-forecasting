# %% [markdown]
# # Step 1: Data Cleaning
# # This notebook loads the raw dataset and applies data cleaning steps.

# %%
import sys
sys.path.append("../src")

from utils import load_data, clean_data

# Load dataset
df = load_data()

# Clean dataset
df = clean_data(df)

# Preview first 5 rows
display(df.head())

# Basic checks
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nMissing values:\n", df.isnull().sum())
# Out:
#   Violation_ID           Violation_Type  Fine_Amount       Location  \
# 0    VLT100000              Overloading         4544      Karnataka
# 1    VLT100001  Driving Without License         2776         Punjab
# 2    VLT100002       Using Mobile Phone         4785    Maharashtra
# 3    VLT100003              No Seatbelt         1138  Uttar Pradesh
# 4    VLT100004            Over-speeding         1610      Karnataka
#
#         Date      Time Vehicle_Type Vehicle_Color  Vehicle_Model_Year  \
# 0 2023-01-01  23:02:00          Car           Red                2012
# 1 2023-01-02  00:42:00      Scooter        Silver                2010
# 2 2023-01-03  04:32:00      Scooter          Grey                2006
# 3 2023-01-04  15:06:00          Car         Green                1996
# 4 2023-01-05  06:57:00        Truck        Yellow                2016
#
#   Registration_State  ...  Recorded_Speed Alcohol_Level Breathalyzer_Result  \
# ...
