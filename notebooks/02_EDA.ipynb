# %% [markdown]
# # Step 2: Exploratory Data Analysis (EDA)
# # We explore traffic violations with plots and descriptive statistics.

# %%
import sys
sys.path.append("../src")

from utils import load_data, clean_data
from visualization_utils import (
    plot_top_violations, plot_fine_distribution, plot_statewise_violations,
    plot_gender_distribution, plot_age_distribution,
    plot_weather_conditions, plot_road_conditions
)

# Load + clean dataset
df = clean_data(load_data())

# Top violations
plot_top_violations(df)

# Fine distribution
plot_fine_distribution(df)

# More EDA
plot_statewise_violations(df)
plot_gender_distribution(df)
plot_age_distribution(df)
plot_weather_conditions(df)
plot_road_conditions(df)
# Out:
# C:\Users\RUCHITHA REDDY\OneDrive\Desktop\traffic voilation analysis\notebooks\../src\visualization_utils.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=violation_counts.values, y=violation_counts.index, palette="viridis")
# C:\Users\RUCHITHA REDDY\OneDrive\Desktop\traffic voilation analysis\notebooks\../src\visualization_utils.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=state_counts.values, y=state_counts.index, palette="magma")
# C:\Users\RUCHITHA REDDY\OneDrive\Desktop\traffic voilation analysis\notebooks\../src\visualization_utils.py:37: FutureWarning:
#
# ...
